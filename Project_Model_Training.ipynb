# %% [markdown]
# # Multi-Agent Deep Reinforcement Learning for Liquidation Strategy Analysis - Model Training

# %%
import utils
import numpy as np
import pandas as pd
import seaborn as sns

# Get the default financial and AC Model parameters
financial_params, ac_params = utils.get_env_param()

# %%
financial_params
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
ac_params
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
# (1M) After making suitable adjustments to syntheticChrissAlmgren.py and utils.py
utils.train_single_agent_scenario()
# Out:
# Episode [100/10000]	Average Shortfall for Agent1: $2,335,017.60
# Episode [200/10000]	Average Shortfall for Agent1: $2,562,462.46
# Episode [300/10000]	Average Shortfall for Agent1: $2,562,500.00
# Episode [400/10000]	Average Shortfall for Agent1: $2,562,500.00
# Episode [500/10000]	Average Shortfall for Agent1: $2,562,500.00
# Episode [600/10000]	Average Shortfall for Agent1: $2,562,500.00
# Episode [700/10000]	Average Shortfall for Agent1: $2,562,500.00
# Episode [800/10000]	Average Shortfall for Agent1: $2,562,500.00
# Episode [900/10000]	Average Shortfall for Agent1: $2,562,500.00
# Episode [1000/10000]	Average Shortfall for Agent1: $2,562,500.00
# Episode [1100/10000]	Average Shortfall for Agent1: $2,562,500.00
# Episode [1200/10000]	Average Shortfall for Agent1: $2,562,500.00
# Episode [1300/10000]	Average Shortfall for Agent1: $2,562,500.00
# Episode [1400/10000]	Average Shortfall for Agent1: $2,562,500.00
# Episode [1500/10000]	Average Shortfall for Agent1: $2,562,500.00
# ...

# %%
# (0.3M) After making suitable adjustments to syntheticChrissAlmgren.py and utils.py
utils.train_single_agent_scenario()
# Out:
# Episode [100/10000]	Average Shortfall for Agent1: $222,180.33
# Episode [200/10000]	Average Shortfall for Agent1: $243,746.47
# Episode [300/10000]	Average Shortfall for Agent1: $243,750.00
# Episode [400/10000]	Average Shortfall for Agent1: $243,750.00
# Episode [500/10000]	Average Shortfall for Agent1: $243,750.00
# Episode [600/10000]	Average Shortfall for Agent1: $243,750.00
# Episode [700/10000]	Average Shortfall for Agent1: $243,750.00
# Episode [800/10000]	Average Shortfall for Agent1: $243,750.00
# Episode [900/10000]	Average Shortfall for Agent1: $243,750.00
# Episode [1000/10000]	Average Shortfall for Agent1: $243,750.00
# Episode [1100/10000]	Average Shortfall for Agent1: $243,750.00
# Episode [1200/10000]	Average Shortfall for Agent1: $243,750.00
# Episode [1300/10000]	Average Shortfall for Agent1: $243,750.00
# Episode [1400/10000]	Average Shortfall for Agent1: $243,750.00
# Episode [1500/10000]	Average Shortfall for Agent1: $243,750.00
# ...

# %%
# (0.7M) After making suitable adjustments to syntheticChrissAlmgren.py and utils.py
utils.train_single_agent_scenario()
# Out:
# Episode [100/10000]	Average Shortfall for Agent1: $1,158,119.59
# Episode [200/10000]	Average Shortfall for Agent1: $1,268,551.72
# Episode [300/10000]	Average Shortfall for Agent1: $1,268,750.00
# Episode [400/10000]	Average Shortfall for Agent1: $1,268,750.00
# Episode [500/10000]	Average Shortfall for Agent1: $1,268,750.00
# Episode [600/10000]	Average Shortfall for Agent1: $1,268,750.00
# Episode [700/10000]	Average Shortfall for Agent1: $1,268,750.00
# Episode [800/10000]	Average Shortfall for Agent1: $1,268,750.00
# Episode [900/10000]	Average Shortfall for Agent1: $1,268,750.00
# Episode [1000/10000]	Average Shortfall for Agent1: $1,268,750.00
# Episode [1100/10000]	Average Shortfall for Agent1: $1,268,750.00
# Episode [1200/10000]	Average Shortfall for Agent1: $1,268,750.00
# Episode [1300/10000]	Average Shortfall for Agent1: $1,268,750.00
# Episode [1400/10000]	Average Shortfall for Agent1: $1,251,646.93
# Episode [1500/10000]	Average Shortfall for Agent1: $630,902.40
# ...

# %%
# (1e-04) After making suitable adjustments to syntheticChrissAlmgren.py and utils.py
utils.train_single_agent_scenario()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
# (1e-09) After making suitable adjustments to syntheticChrissAlmgren.py and utils.py
utils.train_single_agent_scenario()
# Out:
# Episode [100/10000]	Average Shortfall for Agent1: $597,293.35
# Episode [200/10000]	Average Shortfall for Agent1: $656,250.00
# Episode [300/10000]	Average Shortfall for Agent1: $656,250.00
# Episode [400/10000]	Average Shortfall for Agent1: $656,250.00
# Episode [500/10000]	Average Shortfall for Agent1: $656,250.00
# Episode [600/10000]	Average Shortfall for Agent1: $656,250.00
# Episode [700/10000]	Average Shortfall for Agent1: $656,250.00
# Episode [800/10000]	Average Shortfall for Agent1: $656,250.00
# Episode [900/10000]	Average Shortfall for Agent1: $656,250.00
# Episode [1000/10000]	Average Shortfall for Agent1: $656,250.00
# Episode [1100/10000]	Average Shortfall for Agent1: $656,250.00
# Episode [1200/10000]	Average Shortfall for Agent1: $656,250.00
# Episode [1300/10000]	Average Shortfall for Agent1: $656,250.00
# Episode [1400/10000]	Average Shortfall for Agent1: $656,250.00
# Episode [1500/10000]	Average Shortfall for Agent1: $656,250.00
# ...

# %%
# (1e-04 and 1e-09) After making suitable adjustments to syntheticChrissAlmgren.py and utils.py
utils.train_multi_agent_scenario()
# Out:
# Episode [100/10000]	Average Shortfall for Agent1: $1,164,941.51
# Episode [100/10000]	Average Shortfall for Agent2: $1,183,638.91
# Episode [200/10000]	Average Shortfall for Agent1: $1,281,220.13
# Episode [200/10000]	Average Shortfall for Agent2: $1,281,238.68
# Episode [300/10000]	Average Shortfall for Agent1: $1,281,250.00
# Episode [300/10000]	Average Shortfall for Agent2: $1,281,250.00
# Episode [400/10000]	Average Shortfall for Agent1: $1,281,250.00
# Episode [400/10000]	Average Shortfall for Agent2: $1,281,250.00
# Episode [500/10000]	Average Shortfall for Agent1: $1,281,250.00
# Episode [500/10000]	Average Shortfall for Agent2: $1,281,250.00
# Episode [600/10000]	Average Shortfall for Agent1: $1,277,973.12
# Episode [600/10000]	Average Shortfall for Agent2: $1,280,082.86
# Episode [700/10000]	Average Shortfall for Agent1: $679,787.05
# Episode [700/10000]	Average Shortfall for Agent2: $727,973.09
# Episode [800/10000]	Average Shortfall for Agent1: $314,858.72
# ...

# %%
# After making suitable adjustments to syntheticChrissAlmgren.py and utils.py
utils.train_multi_agent_scenario(coop_or_comp="competition")
# Out:
# Episode [100/10000]	Average Shortfall for Agent1: $1,167,687.86
# Episode [100/10000]	Average Shortfall for Agent2: $1,179,277.06
# Episode [200/10000]	Average Shortfall for Agent1: $1,279,112.99
# Episode [200/10000]	Average Shortfall for Agent2: $1,276,300.17
# Episode [300/10000]	Average Shortfall for Agent1: $761,887.88
# Episode [300/10000]	Average Shortfall for Agent2: $776,266.31
# Episode [400/10000]	Average Shortfall for Agent1: $589,703.12
# Episode [400/10000]	Average Shortfall for Agent2: $390,644.38
# Episode [500/10000]	Average Shortfall for Agent1: $365,993.49
# Episode [500/10000]	Average Shortfall for Agent2: $351,873.56
# Episode [600/10000]	Average Shortfall for Agent1: $347,867.41
# Episode [600/10000]	Average Shortfall for Agent2: $348,298.31
# Episode [700/10000]	Average Shortfall for Agent1: $302,789.39
# Episode [700/10000]	Average Shortfall for Agent2: $296,596.55
# Episode [800/10000]	Average Shortfall for Agent1: $305,151.05
# ...

# %%
# After making suitable adjustments to syntheticChrissAlmgren.py and utils.py
utils.train_multi_agent_scenario(coop_or_comp="cooperation")
# Out:
# Episode [100/10000]	Average Shortfall for Agent1: $1,167,001.36
# Episode [100/10000]	Average Shortfall for Agent2: $1,185,113.45
# Episode [200/10000]	Average Shortfall for Agent1: $1,281,146.33
# Episode [200/10000]	Average Shortfall for Agent2: $1,281,210.48
# Episode [300/10000]	Average Shortfall for Agent1: $1,281,250.00
# Episode [300/10000]	Average Shortfall for Agent2: $1,281,250.00
# Episode [400/10000]	Average Shortfall for Agent1: $1,281,250.00
# Episode [400/10000]	Average Shortfall for Agent2: $1,281,250.00
# Episode [500/10000]	Average Shortfall for Agent1: $1,281,250.00
# Episode [500/10000]	Average Shortfall for Agent2: $1,281,250.00
# Episode [600/10000]	Average Shortfall for Agent1: $1,281,250.00
# Episode [600/10000]	Average Shortfall for Agent2: $1,281,250.00
# Episode [700/10000]	Average Shortfall for Agent1: $1,281,250.00
# Episode [700/10000]	Average Shortfall for Agent2: $1,281,250.00
# Episode [800/10000]	Average Shortfall for Agent1: $1,096,864.58
# ...
